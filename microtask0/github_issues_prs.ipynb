# %%
import json
import pandas as pd

# %%
with open('../github_data.json') as x:
    for line in x.readlines():
        y = json.loads(line)
#     print(json.dumps(y, indent=4).keys)
#     print(type(y))
#    print_keys(y["data"])
        if("pull_request" in y["data"].keys()):
            print(y["data"]["pull_request"]["url"])
#     i = y.columns[0]
# #     print(i)
# #     print(y[i][:10])
        
#     print(type(y[y.columns[0]]))
# Out:
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/3
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/5
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/4
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/2
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/6
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/7
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/15
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/14
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/11
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/10
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/12
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/23
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/25
# https://api.github.com/repos/chaoss/grimoirelab-perceval/pulls/29
# ...

# %%
count = 0

def print_keys(y):
    print(count)
    if (type(y) != dict): return 0
    
    else:
        print(y.keys())
        for i in y.keys():
            print_keys(y[i])

# %%
def abc():
    print("hi")

# %%
t = property()

# %%
t.setter(abc)

# %%
t.getter(abc)

# %%
print(t)
